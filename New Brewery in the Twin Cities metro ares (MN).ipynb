# %% [markdown]
# # Introduction

# %% [markdown]
# #### <u> Business goal : identify the best location for a new brewery in the Twin Cities metro area .</u>
# The brewery market in Minnesota had exploded ove the last years. The total production of beer doubled in the last decade <sup> 1 </sup>. The twin cities brewey and taproom market is booming but it still has room for more development when compared to other similar metro areas across the US such as Portland, OR, and Denver, CO which have significant more breweries per capita <sup> 1 </sup>. Since I live in the twic cities and I enjoy visiting the breweries I though to use this project and identify which cities in the Twin Cities metro area could be the home to the next brewery. Any number of investors in the ci
#
# <sup> 1 </sup> https://www.mprnews.org/story/2019/05/15/taproom-beer-minnesota-growth-surly

# %% [markdown]
# # Data

# %% [markdown]
# The Foursquare API was used to retrieve the venue data from all the cities in the Twin Cities metro area. A detailed list of all the cities in the metro was retrieved from the https://www.zipcodestogo.com/Minnesota/ webpage.
# My assumption is that if a city that does not have as brewery is similar in character (i.e. has similar top venues categories) with a city that has a brewery is a good candidate. Further future analysis that takes into account financial performances of different breweries could help improve the recomndation.
